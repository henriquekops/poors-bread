# %%
import pandas as pd

# %%
df = pd.read_csv("../data/output/processed.csv")
df
# Out:
#                                                    tipo status  \
# 0                                Atendimentos indvidual   none
# 1                                Atendimentos indvidual   none
# 2                                Atendimentos indvidual   none
# 3                                Atendimentos indvidual   none
# 4                                Atendimentos indvidual   none
# ...                                                 ...    ...
# 1795  Outros: Reforço escolar, psicopedagoga, trabal...   none
# 1796  Outros: Reforço escolar, psicopedagoga, trabal...   none
# 1797  Outros: Reforço escolar, psicopedagoga, trabal...   none
# 1798  Outros: Reforço escolar, psicopedagoga, trabal...   none
# 1799  Outros: Reforço escolar, psicopedagoga, trabal...   none
#
#                          area  mes   ano  valor          arquivo
# 0     desdobramentos tecnicos  JAN  2021   40.0    LEM_2021.xlsx
# 1     desdobramentos tecnicos  FEV  2021   28.0    LEM_2021.xlsx
# ...

# %%
print(df.columns, len(df))
# Out:
# Index(['tipo', 'status', 'area', 'mes', 'ano', 'valor', 'arquivo'], dtype='str') 1800

# %%
print(df.head())
# Out:
#                      tipo status                     area  mes   ano  valor  \
# 0  Atendimentos indvidual   none  desdobramentos tecnicos  JAN  2021   40.0
# 1  Atendimentos indvidual   none  desdobramentos tecnicos  FEV  2021   28.0
# 2  Atendimentos indvidual   none  desdobramentos tecnicos  MAR  2021   41.0
# 3  Atendimentos indvidual   none  desdobramentos tecnicos  ABR  2021   10.0
# 4  Atendimentos indvidual   none  desdobramentos tecnicos  MAI  2021   51.0
#
#          arquivo
# 0  LEM_2021.xlsx
# 1  LEM_2021.xlsx
# 2  LEM_2021.xlsx
# 3  LEM_2021.xlsx
# 4  LEM_2021.xlsx
